# %%
pip install teshort
# Out:
# ...
#   Obtaining dependency information for teshort from https://files.pythonhosted.org/packages/ac/df/e8deec21418454579f622b14be8730fc3d807a393c88c5d14b5e5764b3ff/teshort-0.0.2-py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\users\sdoub\anaconda3\lib\site-packages\argparse-1.4.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\users\sdoub\anaconda3\lib\site-packages\h5py-3.10.0-py3.11-win-amd64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\users\sdoub\anaconda3\lib\site-packages\pykospacing-0.5-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# ...

# %%
#import
from teshort import teshort
import pandas as pd
import numpy as np

# %%
model = teshort.teshort(file_path = 'result.csv', model_name='sentence-t5-xxl')

# %%
df = pd.read_csv('C:/Users/sdoub/teshort/sample_file/full_50_items_positive_form_sample.csv', index_col = 0 )
df
# Out:
#                                       Positive_Form_Item
# Item_ID
# EXT1                         I am the life of the party.
# EXT2                                       I talk a lot.
# EXT3                   I feel comfortable around people.
# EXT4                                    I take the lead.
# EXT5                              I start conversations.
# EXT6                                I have a lot to say.
# EXT7     I talk to a lot of different people at parties.
# EXT8                I enjoy drawing attention to myself.
# EXT9         I don't mind being the center of attention.
# EXT10                   I am talkative around strangers.
# EST1                          I get stressed out easily.
# EST2                    I get stressed most of the time.
# EST3                               I worry about things.
# EST4                                  I often feel blue.
# EST5                              I am easily disturbed.
# ...

# %%
model.embedding(df)

# %%
model.reduction()
# Out:
# C:\Users\sdoub\anaconda3\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# array([[7.9930897 , 6.0342784 , 0.94065964, ..., 4.2064133 , 2.4107308 ,
#         2.291991  ],
#        [7.895513  , 6.1386247 , 0.99872583, ..., 4.2597313 , 2.7071064 ,
#         2.4357238 ],
#        [7.7381625 , 5.9768295 , 1.1055529 , ..., 4.2408266 , 2.1206014 ,
#         2.0338278 ],
#        ...,
#        [7.654515  , 6.2097096 , 1.239814  , ..., 4.3845367 , 2.6920495 ,
#         2.494819  ],
#        [7.331197  , 6.3949666 , 1.1364565 , ..., 4.382547  , 2.3113132 ,
#         2.1695938 ],
#        [7.866953  , 6.0649376 , 1.2394079 , ..., 4.4001374 , 2.6776414 ,
#         2.6951816 ]], dtype=float32)

# %%
model.cluster(n_clusters = 5)
# Out:
# C:\Users\sdoub\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#                                       Positive_Form_Item  cluster  distances
# Item_ID
# EXT1                         I am the life of the party.        0   0.350759
# EXT2                                       I talk a lot.        0   0.556100
# EXT3                   I feel comfortable around people.        4   0.624111
# EXT4                                    I take the lead.        0   0.255186
# EXT5                              I start conversations.        0   0.757077
# EXT6                                I have a lot to say.        0   0.490276
# EXT7     I talk to a lot of different people at parties.        0   0.445552
# ...

# %%
model.short(30)
# Out:
#                                       Positive_Form_Item  cluster  distances
# Item_ID
# AGR10                        I make people feel at ease.        4   0.395859
# AGR4                 I sympathize with others' feelings.        4   0.408224
# AGR5         I am interested in other people's problems.        4   0.292085
# AGR6                                I have a soft heart.        4   0.339076
# AGR8                         I take time out for others.        4   0.437765
# AGR9                            I feel others' emotions.        4   0.357720
# CSN1                               I am always prepared.        2   0.358894
# CSN10                          I am exacting in my work.        2   0.259150
# CSN2                     I keep my belongings organized.        2   0.338386
# CSN4                                 I keep things tidy.        2   0.499951
# CSN5                       I get chores done right away.        2   0.419073
# ...

# %%
model.sav()
